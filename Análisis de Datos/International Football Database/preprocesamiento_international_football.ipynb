# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_matches = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fuentes/all_matches.csv')
df_country = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/fuentes/countries_names.csv')

# %%
df_matches.head()
# Out:
#          date home_team away_team  home_score  away_score tournament  \
# 0  1872-11-30  Scotland   England           0           0   Friendly
# 1  1873-03-08   England  Scotland           4           2   Friendly
# 2  1874-03-07  Scotland   England           2           1   Friendly
# 3  1875-03-06   England  Scotland           2           2   Friendly
# 4  1876-03-04  Scotland   England           3           0   Friendly
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df_country.head()
# Out:
#   original_name current_name
# 0   Afghanistan  Afghanistan
# 1       Albania      Albania
# 2       Algeria      Algeria
# 3       Andorra      Andorra
# 4        Angola       Angola

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49012 entries, 0 to 49011
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        49012 non-null  object
#  1   home_team   49012 non-null  object
#  2   away_team   49012 non-null  object
#  3   home_score  49012 non-null  int64
#  4   away_score  49012 non-null  int64
#  5   tournament  49012 non-null  object
#  6   country     49012 non-null  object
#  7   neutral     49012 non-null  bool
# dtypes: bool(1), int64(2), object(5)
# memory usage: 2.7+ MB

# %% [markdown]
# No tiene datos faltantes.

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   original_name  289 non-null    object
#  1   current_name   289 non-null    object
# dtypes: object(2)
# memory usage: 4.6+ KB

# %% [markdown]
# No tiene datos faltantes.

# %%
df_matches.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No tiene datos duplicados.

# %%
df_country.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No tiene datos duplicados.

# %%
df_matches['tournament'].unique()
# Out:
# array(['Friendly', 'British Championship', 'Lipton Cup', 'Newton Cup',
#        'Copa Premio Honor Argentino', 'Olympic Games',
#        'Copa Cent Rev Mayo', 'Copa Premio Honor Uruguayo',
#        'Montevideo Cup', 'Far Eastern Games', 'Friendly tournament',
#        'Copa Circulo de la Prensa', 'Roca Cup', 'South American Champ',
#        'C American Indep Cent Cup', 'King Alexander Cup',
#        'Rosa Chevallier Boutell Cup', 'Nordic Championship',
#        'Gossage Cup', 'Trans-Caucasian Champ', 'International Cup',
#        'Baltic Cup', 'Balkan Cup', 'Central American Games', 'World Cup',
#        'Rio Branco Cup', 'World Cup qualifier', 'Hector Gomez Cup',
#        'Juan Mignaburu Cup', 'Eduard Benes Cup',
#        'World Cup q & Nordic Ch', 'King Carol Cup',
#        'C Am & Caribbean Games', 'Bolivarian Games', 'Danube Cup',
#        'Danube C & King Mihai C', 'CCCF Championship',
#        'Balkan & C European Champ', 'North American Champ',
# ...

# %%
df_matches['neutral'].unique()
# Out:
# array([False,  True])
